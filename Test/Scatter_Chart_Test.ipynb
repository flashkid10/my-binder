# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()

# %%
import plotly.express as px
# %matplotlib inline
# %run ~/Data/Core.ipynb

# %%
Process_All()

# %%
Tab_Cla = pd.read_csv('/home/jovyan/Data/Class_Level.csv')
Tab_Cla2= Tab_Cla.query("Class!=Tag3 and C_Count>0 and L_Count>0")
#print(Tab_Cla2)

# %%
fig = px.scatter(Tab_Cla2, x="L_Count", y="C_Count", color="Tag3", symbol="Class")
fig.update_layout(scattermode="group", scattergap=0.75)
fig.show()

# %%
fig = px.line(Tab_Cla2, x="L_Count", y="C_Count", color="Class", markers=True)#symbol="Class"
fig.update_layout(scattergap=0.75)
fig.show()

# %%
fig = px.scatter(Tab_Cla2, x="Class", y="C_Count", color="Tag3")
fig.update_layout(scattermode="group")
fig.show()

# %%
fig = px.scatter(Tab_Cla2, x="Class", y="L_Count", size="C_Count", color="Tag3")
fig.update_layout(scattermode="group")
fig.show()

# %%
fig = px.scatter(Tab_Cla2, x="Class", y="C_Count", size="L_Count", color="Tag3")
fig.update_layout(scattermode="group")
fig.show()

# %%
#fig = px.line(Tab_Cla2, x="L_Count", y="C_Count", color="Class", markers=True)#symbol="Class"
fig = px.line_polar(Tab_Cla2, r="C_Count", theta="L_Count", color="Class")#, line_close=True
fig.update_layout(scattermode="group", scattergap=0.75)
fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
df = px.data.wind()
fig = px.line_polar(df, r="frequency", theta="direction", color="strength", 
                    color_discrete_sequence=px.colors.sequential.Plasma_r,
                    template="plotly_dark",)
fig.show()

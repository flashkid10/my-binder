# %%
import pandas as pd
import plotly.express as px
import numpy as np
pd.set_option("mode.chained_assignment", None)

# %run ~/Data/Core.ipynb
Process_Class_Level()
Table_Class_Level = pd.read_csv('/home/jovyan/Data/Class_Level.csv')

# %%
Display_Fig(Table_Class_Level, ["Class", "Sub-Class", "C_Count"])

# %%
Display_Fig(Table_Class_Level, ["Class", "Sub-Class", "L_Count"])

# %%
def setup_ui(df):
    
    out = widgets.Output()
    with out:
        display(df)
    return out

# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline


Fig1=Display_Fig(Table_Class_Level, ["Class", "Sub-Class", "C_Count"])
Fig2=Display_Fig(Table_Class_Level, ["Class", "Sub-Class", "L_Count"])


VB1 = setup_ui(Fig1)
VB2 = setup_ui(Fig2)

tab1 = VB1
tab2 = VB2


tab = widgets.Tab(children=[tab1, tab2])
tab.set_title(0, 'plot')
tab.set_title(1, 'styling')
display(tab)

# %%
import pandas as pd
import plotly.express as px
import numpy as np
pd.set_option("mode.chained_assignment", None)

# %run Data/Core.ipynb
Process_Class_Level()
Table_Class_Level = pd.read_csv('/home/jovyan/Data/Class_Level.csv')

# %%
Display_Fig(Table_Class_Level, ["Class", "Sub-Class", "C_Count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 Display_Fig(Table_Class_Level, ["Class", "Sub-Class", "C_Count"])
#
# File /tmp/ipykernel_67/2961626540.py:9, in Display_Fig(Table, Arr)
#       6         SF.drop(y2)
#       8 for x2, y2 in SF.iterrows():
# ----> 9     if y2[Arr[0]]==null or y2[Arr[1]]==null or y2[Arr[2]]==null:
#      10         SF.drop(y2)
#      16 SF["All"] = "All" # in order to have a single root node
#
# NameError: name 'null' is not defined

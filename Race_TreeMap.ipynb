# %%
# libraries
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
import pandas as pd


spreadsheet = pd.read_csv('/home/jovyan/Data/Characters.csv')

Races_Raw = spreadsheet['Race'].tolist()

Races_No_Dups = [*set(Races_Raw)]

Race_Count = []

my_dict = {i:Races_Raw.count(i) for i in Races_Raw}


#mylist = ["group A", "group B", "group C", "group D"]
#print(my_dict)

## Create a data frame with fake data
df = pd.DataFrame({'nb_people':my_dict.values(), 'group':my_dict.keys() })

## plot it
squarify.plot(sizes=df['nb_people'], label=df['group'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
import sys
sys.path.insert(0, '../src')

import pandas as pd
import matplotlib.pyplot as plt

import mpl_extra.treemap as tr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 7
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
# ----> 7 import mpl_extra.treemap as tr
#
# ModuleNotFoundError: No module named 'mpl_extra'

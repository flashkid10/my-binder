# %%
import pandas as pd
import plotly.express as px
import numpy as np
pd.set_option("mode.chained_assignment", None)

# %run Data/Core.ipynb
Process_Race()

#SHT_Characters = pd.read_csv('/home/jovyan/Data/Characters.csv')
Table_Race = pd.read_csv('/home/jovyan/Data/Race.csv')


#for x2, y2 in SHT_Race.iterrows():
    #SHT_Race.at[x2,'Count'] = 0

#for x1, y1 in SHT_Characters.iterrows():
    #for x2, y2 in SHT_Race.iterrows():
        ##print(x2)
        #if y2[4]==y1[5]:
            ##y2[6]+=1
            #SHT_Race.at[x2,'Count'] += 1
            
#SHT_Race.to_csv('/home/jovyan/Data/Race.csv', index=False) #<<<<<<<

# %%
def Display_Race(Arr):
    SF = Table_Race[[Arr[0], Arr[1], Arr[2]]]
        
    #SFL = []    
    #for x,y in SF.iterrows():
        #if y[2] > 0:
            #SFL.append(y)
    #mat1 = np.array(SF)
    #print(mat1[:, 2])
        
    SF["All"] = "All" # in order to have a single root node
    fig = px.treemap(SF,
                     path=['All', Arr[0], Arr[1]],
                     values=Arr[2],
                     color=Arr[2],
                     color_continuous_scale='RdBu',
                    )
    fig.update_traces(root_color="lightgrey")

    
   
    fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))
    fig.update_layout(autosize=False,width=1100,height=800)
    #fig.update_layout(autosize=True)   
    return fig

# %%
Display_Race(["Source", "Race", "Count"])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 Display_Race(["Source", "Race", "Count"])
#
# Cell In[68], line 12, in Display_Race(Arr)
#       4 #SFL = []
#       5 #for x,y in SF.iterrows():
#       6     #if y[2] > 0:
#       7         #SFL.append(y)
#       8 #mat1 = np.array(SF)
#       9 #print(mat1[:, 2])
#      11 SF["All"] = "All" # in order to have a single root node
# ---> 12 fig = px.treemap(SF,
#      13                  path=['All', Arr[0], Arr[1]],
#      14                  values=Arr[2],
#      15                  color=Arr[2],
#      16                  color_continuous_scale='RdBu',
#      17                 )
#      18 fig.update_traces(root_color="lightgrey")
#      22 fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_chart_types.py:1591, in treemap(data_frame, names, values, parents, ids, path, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1589 if path is not None and branchvalues is None:
#    1590     branchvalues = "total"
# -> 1591 return make_figure(
#    1592     args=locals(),
#    1593     constructor=go.Treemap,
#    1594     trace_patch=dict(branchvalues=branchvalues, maxdepth=maxdepth),
#    1595     layout_patch=layout_patch,
#    1596 )
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_core.py:1998, in make_figure(args, constructor, trace_patch, layout_patch)
#    1996 args = build_dataframe(args, constructor)
#    1997 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 1998     args = process_dataframe_hierarchy(args)
#    1999 if constructor in [go.Pie]:
#    2000     args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_core.py:1623, in process_dataframe_hierarchy(args)
#    1621 for i, level in enumerate(path):
#    1622     df_tree = pd.DataFrame(columns=df_all_trees.columns)
# -> 1623     dfg = df.groupby(path[i:]).agg(agg_f)
#    1624     dfg = dfg.reset_index()
#    1625     # Path label massaging
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1271, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1268 func = maybe_mangle_lambdas(func)
#    1270 op = GroupByApply(self, func, args, kwargs)
# -> 1271 result = op.agg()
#    1272 if not is_dict_like(func) and result is not None:
#    1273     return result
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/apply.py:163, in Apply.agg(self)
#     160     return self.apply_str()
#     162 if is_dict_like(arg):
# --> 163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
#     166     return self.agg_list_like()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/apply.py:420, in Apply.agg_dict_like(self)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
# --> 420         results = {
#     421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/apply.py:421, in <dictcomp>(.0)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
#     420         results = {
# --> 421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:267, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     259     return self.obj._constructor(
#     260         [],
#     261         name=self.obj.name,
#     262         index=self.grouper.result_index,
#     263         dtype=obj.dtype,
#     264     )
#     266 if self.grouper.nkeys > 1:
# --> 267     return self._python_agg_general(func, *args, **kwargs)
#     269 try:
#     270     return self._python_agg_general(func, *args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:289, in SeriesGroupBy._python_agg_general(self, func, *args, **kwargs)
#     286 f = lambda x: func(x, *args, **kwargs)
#     288 obj = self._obj_with_exclusions
# --> 289 result = self.grouper.agg_series(obj, f)
#     290 res = obj._constructor(result, name=obj.name)
#     291 return self._wrap_aggregated_output(res)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:286, in SeriesGroupBy._python_agg_general.<locals>.<lambda>(x)
#     284 def _python_agg_general(self, func, *args, **kwargs):
#     285     func = com.is_builtin_func(func)
# --> 286     f = lambda x: func(x, *args, **kwargs)
#     288     obj = self._obj_with_exclusions
#     289     result = self.grouper.agg_series(obj, f)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_core.py:1604, in process_dataframe_hierarchy.<locals>.aggfunc_continuous(x)
#    1603 def aggfunc_continuous(x):
# -> 1604     return np.average(x, weights=df.loc[x.index, count_colname])
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/numpy/lib/function_base.py:548, in average(a, axis, weights, returned, keepdims)
#     546     scl = wgt.sum(axis=axis, dtype=result_dtype, **keepdims_kw)
#     547     if np.any(scl == 0.0):
# --> 548         raise ZeroDivisionError(
#     549             "Weights sum to zero, can't be normalized")
#     551     avg = avg_as_array = np.multiply(a, wgt,
#     552                       dtype=result_dtype).sum(axis, **keepdims_kw) / scl
#     554 if returned:
#
# ZeroDivisionError: Weights sum to zero, can't be normalized

# %%
Display_Race(["Race", "Tag3", "Count"])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 Display_Race(["Race", "Tag3", "Count"])
#
# Cell In[68], line 12, in Display_Race(Arr)
#       4 #SFL = []
#       5 #for x,y in SF.iterrows():
#       6     #if y[2] > 0:
#       7         #SFL.append(y)
#       8 #mat1 = np.array(SF)
#       9 #print(mat1[:, 2])
#      11 SF["All"] = "All" # in order to have a single root node
# ---> 12 fig = px.treemap(SF,
#      13                  path=['All', Arr[0], Arr[1]],
#      14                  values=Arr[2],
#      15                  color=Arr[2],
#      16                  color_continuous_scale='RdBu',
#      17                 )
#      18 fig.update_traces(root_color="lightgrey")
#      22 fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_chart_types.py:1591, in treemap(data_frame, names, values, parents, ids, path, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1589 if path is not None and branchvalues is None:
#    1590     branchvalues = "total"
# -> 1591 return make_figure(
#    1592     args=locals(),
#    1593     constructor=go.Treemap,
#    1594     trace_patch=dict(branchvalues=branchvalues, maxdepth=maxdepth),
#    1595     layout_patch=layout_patch,
#    1596 )
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_core.py:1998, in make_figure(args, constructor, trace_patch, layout_patch)
#    1996 args = build_dataframe(args, constructor)
#    1997 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 1998     args = process_dataframe_hierarchy(args)
#    1999 if constructor in [go.Pie]:
#    2000     args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_core.py:1623, in process_dataframe_hierarchy(args)
#    1621 for i, level in enumerate(path):
#    1622     df_tree = pd.DataFrame(columns=df_all_trees.columns)
# -> 1623     dfg = df.groupby(path[i:]).agg(agg_f)
#    1624     dfg = dfg.reset_index()
#    1625     # Path label massaging
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1271, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1268 func = maybe_mangle_lambdas(func)
#    1270 op = GroupByApply(self, func, args, kwargs)
# -> 1271 result = op.agg()
#    1272 if not is_dict_like(func) and result is not None:
#    1273     return result
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/apply.py:163, in Apply.agg(self)
#     160     return self.apply_str()
#     162 if is_dict_like(arg):
# --> 163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
#     166     return self.agg_list_like()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/apply.py:420, in Apply.agg_dict_like(self)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
# --> 420         results = {
#     421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/apply.py:421, in <dictcomp>(.0)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
#     420         results = {
# --> 421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:267, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     259     return self.obj._constructor(
#     260         [],
#     261         name=self.obj.name,
#     262         index=self.grouper.result_index,
#     263         dtype=obj.dtype,
#     264     )
#     266 if self.grouper.nkeys > 1:
# --> 267     return self._python_agg_general(func, *args, **kwargs)
#     269 try:
#     270     return self._python_agg_general(func, *args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:289, in SeriesGroupBy._python_agg_general(self, func, *args, **kwargs)
#     286 f = lambda x: func(x, *args, **kwargs)
#     288 obj = self._obj_with_exclusions
# --> 289 result = self.grouper.agg_series(obj, f)
#     290 res = obj._constructor(result, name=obj.name)
#     291 return self._wrap_aggregated_output(res)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pandas/core/groupby/generic.py:286, in SeriesGroupBy._python_agg_general.<locals>.<lambda>(x)
#     284 def _python_agg_general(self, func, *args, **kwargs):
#     285     func = com.is_builtin_func(func)
# --> 286     f = lambda x: func(x, *args, **kwargs)
#     288     obj = self._obj_with_exclusions
#     289     result = self.grouper.agg_series(obj, f)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/plotly/express/_core.py:1604, in process_dataframe_hierarchy.<locals>.aggfunc_continuous(x)
#    1603 def aggfunc_continuous(x):
# -> 1604     return np.average(x, weights=df.loc[x.index, count_colname])
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/numpy/lib/function_base.py:548, in average(a, axis, weights, returned, keepdims)
#     546     scl = wgt.sum(axis=axis, dtype=result_dtype, **keepdims_kw)
#     547     if np.any(scl == 0.0):
# --> 548         raise ZeroDivisionError(
#     549             "Weights sum to zero, can't be normalized")
#     551     avg = avg_as_array = np.multiply(a, wgt,
#     552                       dtype=result_dtype).sum(axis, **keepdims_kw) / scl
#     554 if returned:
#
# ZeroDivisionError: Weights sum to zero, can't be normalized

# %%
import plotly.express as px
 
 
fig = px.treemap(
    names = ["A","B", "C", "D", "E"],
    parents = ["", "A", "B", "C", "A"]
)
 
fig.show()
